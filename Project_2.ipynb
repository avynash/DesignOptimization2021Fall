# %% [markdown]
# <a href="https://colab.research.google.com/github/avynash/DesignOptimization2021Fall/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Static Structural

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Modal Analysis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Transient Thermal

# %% [markdown]
# ![image.png](data:image/png;base64,...)
